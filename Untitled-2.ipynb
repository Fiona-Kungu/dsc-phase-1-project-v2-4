# %%
import pandas as pd
# setting pandas display to avoid scientific notation in my dataframes
pd.options.display.float_format = '{:.2f}'.format
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import requests


# %matplotlib inline

# %%
#getting a preview of the data
movie_budgets_df = pd.read_csv('zippedData/tn.movie_budgets.csv' , index_col=0)
#the first 5
movie_budgets_df.head()
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747

# %%
#getting a preview of the data
movie_budgets_df = pd.read_csv('zippedData/tn.movie_budgets.csv', index_col=0)
#the first 5
movie_budgets_df.head()
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747

# %%
movie_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5782 entries, 1 to 82
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   object
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   object
#  3   domestic_gross     5782 non-null   object
#  4   worldwide_gross    5782 non-null   object
# dtypes: object(5)
# memory usage: 271.0+ KB

# %%
movie_budgets_df.dtypes
# Out:
# release_date         object
# movie                object
# production_budget    object
# domestic_gross       object
# worldwide_gross      object
# dtype: object

# %%
movie_budgets_df['production_budget'] = movie_budgets_df['production_budget'].str.replace('$', "").str.replace(",", "")

# %%
movie_budgets_df['domestic_gross'] = movie_budgets_df['domestic_gross'].str.replace('$', "").str.replace(",", "")

# %%
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].str.replace('$', "").str.replace(",", "")

# %%
movie_budgets_df.head()
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1          425000000      760507625      2776345279
# 2          410600000      241063875      1045663875
# 3          350000000       42762350       149762350
# 4          330600000      459005868      1403013963
# 5          317000000      620181382      1316721747

# %%
def convert_price_to_int64(df, column_name):
    # Remove commas and dollar signs from the column
    df[column_name] = df[column_name].str.replace(',', '', regex=False).str.replace('$', '', regex=False)
    # Convert to int64
    df[column_name] = df[column_name].astype('int64')
    return df

convert_price_to_int64(movie_budgets_df, 'production_budget')
convert_price_to_int64(movie_budgets_df, 'domestic_gross')
convert_price_to_int64(movie_budgets_df, 'worldwide_gross')
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ..           ...                                          ...
# 78  Dec 31, 2018                                       Red 11
# 79   Apr 2, 1999                                    Following
# 80  Jul 13, 2005                Return to the Land of Wonders
# 81  Sep 29, 2015                         A Plague So Pleasant
# 82   Aug 5, 2005                            My Date With Drew
#
#     production_budget  domestic_gross  worldwide_gross
# id
# 1           425000000       760507625       2776345279
# 2           410600000       241063875       1045663875
# 3           350000000        42762350        149762350
# 4           330600000       459005868       1403013963
# 5           317000000       620181382       1316721747
# ..                ...             ...              ...
# 78               7000               0                0
# 79               6000           48482           240495
# 80               5000            1338             1338
# 81               1400               0                0
# 82               1100          181041           181041
#
# [5782 rows x 5 columns]

# %%
movie_budgets_df = movie_budgets_df.loc[~((movie_budgets_df['production_budget'] == 0) | (movie_budgets_df['domestic_gross'] == 0) | (movie_budgets_df['worldwide_gross'] == 0))]

# %%
movie_budgets_df['production_budget'].describe()
# Out:
# count        5234.00
# mean     34033480.05
# std      42960481.08
# min          1100.00
# 25%       6500000.00
# 50%      20000000.00
# 75%      45000000.00
# max     425000000.00
# Name: production_budget, dtype: float64

# %%
movie_budgets_df.columns
# Out:
# Index(['release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')

# %%
movie_budgets_df.isnull().sum()
# Out:
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
# renaming columns
movie_budgets_df = movie_budgets_df.rename(columns = {'released':'release_date', 'domestic_gross':'dom_gross', 'worldwide_gross':'world_gross', 'production_budget': 'budget'})
# showing all column names
movie_budgets_df.columns
# Out:
# Index(['release_date', 'movie', 'budget', 'dom_gross', 'world_gross'], dtype='object')

# %%
movie_budgets_df.head()
# Out:
#     release_date                                        movie     budget  \
# id
# 1   Dec 18, 2009                                       Avatar  425000000
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides  410600000
# 3    Jun 7, 2019                                 Dark Phoenix  350000000
# 4    May 1, 2015                      Avengers: Age of Ultron  330600000
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi  317000000
#
#     dom_gross  world_gross
# id
# 1   760507625   2776345279
# 2   241063875   1045663875
# 3    42762350    149762350
# 4   459005868   1403013963
# 5   620181382   1316721747

# %%
# Filter the DataFrame to include only years above 2015
movie_budgets_df["release_date"] = movie_budgets_df["release_date"].str[-4:]

# %%
movie_budgets_df
# Out:
#    release_date                                        movie     budget  \
# id
# 1          2009                                       Avatar  425000000
# 2          2011  Pirates of the Caribbean: On Stranger Tides  410600000
# 3          2019                                 Dark Phoenix  350000000
# 4          2015                      Avengers: Age of Ultron  330600000
# 5          2017            Star Wars Ep. VIII: The Last Jedi  317000000
# ..          ...                                          ...        ...
# 76         2006                                       Cavite       7000
# 77         2004                              The Mongol King       7000
# 79         1999                                    Following       6000
# 80         2005                Return to the Land of Wonders       5000
# 82         2005                            My Date With Drew       1100
#
#     dom_gross  world_gross
# id
# 1   760507625   2776345279
# 2   241063875   1045663875
# 3    42762350    149762350
# 4   459005868   1403013963
# 5   620181382   1316721747
# ..        ...          ...
# 76      70071        71644
# 77        900          900
# 79      48482       240495
# 80       1338         1338
# 82     181041       181041
#
# [5234 rows x 5 columns]

# %%
df = movie_budgets_df["release_date"].str[-4:]

# %%
df
# Out:
# id
# 1     2009
# 2     2011
# 3     2019
# 4     2015
# 5     2017
#       ...
# 76    2006
# 77    2004
# 79    1999
# 80    2005
# 82    2005
# Name: release_date, Length: 5234, dtype: object

# %%
convert_price_to_int64(movie_budgets_df, 'release_date')
# Out:
#     release_date                                        movie     budget  \
# id
# 1           2009                                       Avatar  425000000
# 2           2011  Pirates of the Caribbean: On Stranger Tides  410600000
# 3           2019                                 Dark Phoenix  350000000
# 4           2015                      Avengers: Age of Ultron  330600000
# 5           2017            Star Wars Ep. VIII: The Last Jedi  317000000
# ..           ...                                          ...        ...
# 76          2006                                       Cavite       7000
# 77          2004                              The Mongol King       7000
# 79          1999                                    Following       6000
# 80          2005                Return to the Land of Wonders       5000
# 82          2005                            My Date With Drew       1100
#
#     dom_gross  world_gross
# id
# 1   760507625   2776345279
# 2   241063875   1045663875
# 3    42762350    149762350
# 4   459005868   1403013963
# 5   620181382   1316721747
# ..        ...          ...
# 76      70071        71644
# 77        900          900
# 79      48482       240495
# 80       1338         1338
# 82     181041       181041
#
# [5234 rows x 5 columns]

# %%
# Filter the DataFrame to include only years above 2015
movie_budgets_df = movie_budgets_df[movie_budgets_df['release_date'] >= 2015]
movie_budgets_df
# Out:
#     release_date                                 movie     budget  dom_gross  \
# id
# 3           2019                          Dark Phoenix  350000000   42762350
# 4           2015               Avengers: Age of Ultron  330600000  459005868
# 5           2017     Star Wars Ep. VIII: The Last Jedi  317000000  620181382
# 6           2015  Star Wars Ep. VII: The Force Awakens  306000000  936662225
# 7           2018                Avengers: Infinity War  300000000  678815482
# ..           ...                                   ...        ...        ...
# 86          2017                         A Ghost Story     100000    1594798
# 2           2015             Dawn of the Crescent Moon      75000       8799
# 20          2015                              Counting      50000       8374
# 38          2016                                Krisha      30000     144822
# 45          2017                                 Emily      27000       3547
#
#     world_gross
# id
# 3     149762350
# 4    1403013963
# 5    1316721747
# 6    2053311220
# 7    2048134200
# ..          ...
# 86      2769782
# 2          8799
# 20         8374
# 38       144822
# 45         3547
#
# [730 rows x 5 columns]

# %%
# show number of rows and columns after filtering
movie_budgets_df.shape
# Out:
# (730, 5)

# %%
movie_budgets_df.isnull().sum()
# Out:
# release_date    0
# movie           0
# budget          0
# dom_gross       0
# world_gross     0
# dtype: int64

# %%
# getting value counts for  column
#movie_budgets_df = movie_budgets_df.groupby(["release_date", "budget"])
#movie_budgets_df.first()

# %%
movie_budgets_df
# Out:
#     release_date                                 movie     budget  dom_gross  \
# id
# 3           2019                          Dark Phoenix  350000000   42762350
# 4           2015               Avengers: Age of Ultron  330600000  459005868
# 5           2017     Star Wars Ep. VIII: The Last Jedi  317000000  620181382
# 6           2015  Star Wars Ep. VII: The Force Awakens  306000000  936662225
# 7           2018                Avengers: Infinity War  300000000  678815482
# ..           ...                                   ...        ...        ...
# 86          2017                         A Ghost Story     100000    1594798
# 2           2015             Dawn of the Crescent Moon      75000       8799
# 20          2015                              Counting      50000       8374
# 38          2016                                Krisha      30000     144822
# 45          2017                                 Emily      27000       3547
#
#     world_gross
# id
# 3     149762350
# 4    1403013963
# 5    1316721747
# 6    2053311220
# 7    2048134200
# ..          ...
# 86      2769782
# 2          8799
# 20         8374
# 38       144822
# 45         3547
#
# [730 rows x 5 columns]

# %%
#add total_gross column in the dataframe that is the total values of domestic_gross and worldwide_gross
movie_budgets_df['total_gross'] = movie_budgets_df['dom_gross'] + movie_budgets_df['world_gross']
#add gross_profits column in the dataframe that is the difference between total_gross and domestic_gross
movie_budgets_df['gross_profits']= movie_budgets_df['total_gross'] - movie_budgets_df['budget']
# Out:
# <ipython-input-185-c9481f1b397d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_budgets_df['total_gross'] = movie_budgets_df['dom_gross'] + movie_budgets_df['world_gross']
# <ipython-input-185-c9481f1b397d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_budgets_df['gross_profits']= movie_budgets_df['total_gross'] - movie_budgets_df['budget']

# %%
movie_budgets_df
# Out:
#     release_date                                 movie     budget  dom_gross  \
# id
# 3           2019                          Dark Phoenix  350000000   42762350
# 4           2015               Avengers: Age of Ultron  330600000  459005868
# 5           2017     Star Wars Ep. VIII: The Last Jedi  317000000  620181382
# 6           2015  Star Wars Ep. VII: The Force Awakens  306000000  936662225
# 7           2018                Avengers: Infinity War  300000000  678815482
# ..           ...                                   ...        ...        ...
# 86          2017                         A Ghost Story     100000    1594798
# 2           2015             Dawn of the Crescent Moon      75000       8799
# 20          2015                              Counting      50000       8374
# 38          2016                                Krisha      30000     144822
# 45          2017                                 Emily      27000       3547
#
#     world_gross  total_gross  gross_profits
# id
# 3     149762350    192524700     -157475300
# 4    1403013963   1862019831     1531419831
# 5    1316721747   1936903129     1619903129
# 6    2053311220   2989973445     2683973445
# 7    2048134200   2726949682     2426949682
# ..          ...          ...            ...
# 86      2769782      4364580        4264580
# 2          8799        17598         -57402
# 20         8374        16748         -33252
# 38       144822       289644         259644
# 45         3547         7094         -19906
#
# [730 rows x 7 columns]

# %%
fig,ax = plt.subplots(figsize = (13,12))
plt.scatter(movie_budgets_df['budget'],  movie_budgets_df['gross_profits'] )
ax.set_xlabel('budget')
ax.set_ylabel('profits')
plt.title('2.4.1 - budget vs.  Profits')
plt.show()

# %%
#data extraction
movie_budgets_df = pd.read_sql
